# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/world-happiness-report-2021/world-happiness-report-2021.csv
# /kaggle/input/world-happiness-report-2021/world-happiness-report.csv

# %%
df1=pd.read_csv('/kaggle/input/world-happiness-report-2021/world-happiness-report-2021.csv')

# %%
df2=pd.read_csv('/kaggle/input/world-happiness-report-2021/world-happiness-report.csv')

# %%
df1
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df2
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df2.nunique()
# Out:
# Country name                         166
# year                                  16
# Life Ladder                         1553
# Log GDP per capita                  1500
# Social support                       455
# Healthy life expectancy at birth     828
# Freedom to make life choices         535
# Generosity                           609
# Perceptions of corruption            572
# Positive affect                      431
# Negative affect                      374
# dtype: int64

# %%
df2.year.value_counts()
# Out:
# 2017    147
# 2011    146
# 2014    145
# 2019    144
# 2015    143
# 2012    142
# 2016    142
# 2018    142
# 2013    137
# 2010    124
# 2009    114
# 2008    110
# 2007    102
# 2020     95
# 2006     89
# 2005     27
# Name: year, dtype: int64

# %%
df2.year.value_counts().plot(kind='pie',figsize=(20, 15)).set_title('Years')
# Out:
# Text(0.5, 1.0, 'Years')

# %%
df2['Country name'].value_counts()
# Out:
# Zimbabwe        15
# South Africa    15
# Tanzania        15
# Denmark         15
# Tajikistan      15
#                 ..
# Maldives         1
# Suriname         1
# Cuba             1
# Oman             1
# Guyana           1
# Name: Country name, Length: 166, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
df2['Country name'].value_counts()[:90].plot(kind='pie',figsize=(50, 25)).set_title('Ninty Counteries')
plt.xticks(fontsize=40,rotation=60)
# Out:
# (array([], dtype=float64), [])

# %%
India = df2[df2['Country name']== 'India']

# %%
India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 732 to 746
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      15 non-null     object
#  1   year                              15 non-null     int64
#  2   Life Ladder                       15 non-null     float64
#  3   Log GDP per capita                15 non-null     float64
#  4   Social support                    15 non-null     float64
#  5   Healthy life expectancy at birth  15 non-null     float64
#  6   Freedom to make life choices      15 non-null     float64
#  7   Generosity                        14 non-null     float64
#  8   Perceptions of corruption         15 non-null     float64
#  9   Positive affect                   15 non-null     float64
#  10  Negative affect                   15 non-null     float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
India.isnull().sum()
# Out:
# Country name                        0
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          1
# Perceptions of corruption           0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
India=India.dropna()

# %%
India.isnull().sum()
# Out:
# Country name                        0
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
India.hist(figsize=(20, 10));

# %%
India.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
India['Social support'].value_counts().plot(kind='hist',figsize=(10, 5)).set_title('Social support')
# Out:
# Text(0.5, 1.0, 'Social support')

# %%
import seaborn as sns

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Social support", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Social support')
sns.lineplot( x = "year", y = "Social support", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Social support');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Healthy life expectancy at birth", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title("India's Healthy life expectancy at birth")
sns.lineplot( x = df2["year"], y = "Healthy life expectancy at birth", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Healthy life expectancy at birth');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Life Ladder", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India "Life Ladder')
sns.lineplot( x = df2["year"], y = "Life Ladder", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World "Life Ladder');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Log GDP per capita", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Log GDP per capita')
sns.lineplot( x = df2["year"], y = "Log GDP per capita", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Log GDP per capita');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Healthy life expectancy at birth", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Healthy life expectancy at birth')
sns.lineplot( x = df2["year"], y = "Healthy life expectancy at birth", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Healthy life expectancy at birth');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Freedom to make life choices", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Freedom to make life choices')
sns.lineplot( x = df2["year"], y = "Freedom to make life choices", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Freedom to make life choices');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Generosity", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Generosity')
sns.lineplot( x = df2["year"], y = "Generosity", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Generosity');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Perceptions of corruption", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Perceptions of corruption')
sns.lineplot( x = df2["year"], y = "Perceptions of corruption", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Perceptions of corruption');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Positive affect", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Positive affect')
sns.lineplot( x = df2["year"], y = "Positive affect", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Positive affect');

# %%
fig,ax =  plt.subplots( 1, 2,
                       figsize = ( 20, 5))
sns.lineplot( x = "year", y = "Negative affect", 
             color = 'b',ci=None,ax = ax[0], data = India, 
             ).set_title('India Negative affect')
sns.lineplot( x = df2["year"], y = "Negative affect", 
             color = 'r',ci=None,ax = ax[1], data = df2, 
             ).set_title('World Negative affect');

# %%
sns.set(rc = {'figure.figsize':(20,8)})
sns.scatterplot( y = 'Life Ladder', x ='Log GDP per capita', hue='Life Ladder'\
                ,data=df2).set_title('In World Relation Btw Life Ladder and GDP per capita ');

# %%
sns.set(rc = {'figure.figsize':(12,4)})
sns.scatterplot( y = 'Life Ladder', x ='Log GDP per capita', hue='Life Ladder'\
                ,data=India).set_title('In India Relation Btw Life Ladder and GDP per capita ');

# %%
sns.set(rc = {'figure.figsize':(12,4)})
sns.scatterplot( y = 'Healthy life expectancy at birth', x ='Log GDP per capita', hue='Healthy life expectancy at birth'\
                ,data=df2).set_title('In World Relation Btw Healthy life expectancy at birth and GDP per capita ');

# %%
sns.set(rc = {'figure.figsize':(12,4)})
sns.scatterplot( y = 'Healthy life expectancy at birth', x ='Log GDP per capita', hue='Healthy life expectancy at birth'\
                ,data=India).set_title('In India Relation Btw Healthy life expectancy at birth and GDP per capita ');

# %%
sns.set(rc = {'figure.figsize':(12,4)})
sns.scatterplot( x = 'Freedom to make life choices', y ='Social support', hue='Social support'\
                ,data=df2).set_title('In India Relation Btw Healthy life expectancy at birth and GDP per capita ');

# %%
sns.set(rc = {'figure.figsize':(12,4)})
sns.scatterplot( x = 'Freedom to make life choices', y ='Social support', hue='Social support'\
                ,data=India).set_title('In India Relation Btw Healthy life expectancy at birth and GDP per capita ');

# %%
India.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
India['Social support'].values
# Out:
# array([0.569, 0.684, 0.653, 0.605, 0.553, 0.511, 0.553, 0.621, 0.61 ,
#        0.614, 0.607, 0.638, 0.561, 0.617])
